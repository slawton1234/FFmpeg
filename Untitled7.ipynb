# %% [markdown]
# <a href="https://colab.research.google.com/github/slawton1234/FFmpeg/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= 123
print(a)
# Out:
# 123
